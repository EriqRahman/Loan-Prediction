# %%
import numpy as np
import pandas as pd

# %%
train_data=pd.read_csv('/content/drive/MyDrive/prac/LOAN PREDICT/train_ctrUa4K.csv')
test_data=pd.read_csv('/content/drive/MyDrive/prac/LOAN PREDICT/test_lAUu6dG.csv')

# %%
train_data
# Out:
#       Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001002    Male      No  ...            1.0         Urban           Y
# 1    LP001003    Male     Yes  ...            1.0         Rural           N
# 2    LP001005    Male     Yes  ...            1.0         Urban           Y
# 3    LP001006    Male     Yes  ...            1.0         Urban           Y
# 4    LP001008    Male      No  ...            1.0         Urban           Y
# ..        ...     ...     ...  ...            ...           ...         ...
# 609  LP002978  Female      No  ...            1.0         Rural           Y
# 610  LP002979    Male     Yes  ...            1.0         Rural           Y
# 611  LP002983    Male     Yes  ...            1.0         Urban           Y
# 612  LP002984    Male     Yes  ...            1.0         Urban           Y
# 613  LP002990  Female      No  ...            0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
train_data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df_1= train_data[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area','Loan_Status']].copy()

# %%
df_1
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Property_Area  Loan_Status
# 0               5849                0.0  ...          Urban            Y
# 1               4583             1508.0  ...          Rural            N
# 2               3000                0.0  ...          Urban            Y
# 3               2583             2358.0  ...          Urban            Y
# 4               6000                0.0  ...          Urban            Y
# ..               ...                ...  ...            ...          ...
# 609             2900                0.0  ...          Rural            Y
# 610             4106                0.0  ...          Rural            Y
# 611             8072              240.0  ...          Urban            Y
# 612             7583                0.0  ...          Urban            Y
# 613             4583                0.0  ...      Semiurban            N
#
# [614 rows x 7 columns]

# %%
df_1.isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
le=le = preprocessing.LabelEncoder()
df_1['Property_Area'] = le.fit_transform(df_1['Property_Area'])

# %%
df_1
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Property_Area  Loan_Status
# 0               5849                0.0  ...              2            Y
# 1               4583             1508.0  ...              0            N
# 2               3000                0.0  ...              2            Y
# 3               2583             2358.0  ...              2            Y
# 4               6000                0.0  ...              2            Y
# ..               ...                ...  ...            ...          ...
# 609             2900                0.0  ...              0            Y
# 610             4106                0.0  ...              0            Y
# 611             8072              240.0  ...              2            Y
# 612             7583                0.0  ...              2            Y
# 613             4583                0.0  ...              1            N
#
# [614 rows x 7 columns]

# %%
df_1['Credit_History'].fillna(df_1['Credit_History'].mode().iloc[0],inplace=True)

# %%
df_1.isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df_1
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Property_Area  Loan_Status
# 0               5849                0.0  ...              2            Y
# 1               4583             1508.0  ...              0            N
# 2               3000                0.0  ...              2            Y
# 3               2583             2358.0  ...              2            Y
# 4               6000                0.0  ...              2            Y
# ..               ...                ...  ...            ...          ...
# 609             2900                0.0  ...              0            Y
# 610             4106                0.0  ...              0            Y
# 611             8072              240.0  ...              2            Y
# 612             7583                0.0  ...              2            Y
# 613             4583                0.0  ...              1            N
#
# [614 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scale_features_mm = MinMaxScaler()
df_1["ApplicantIncome"] = scale_features_mm.fit_transform(df_1[["ApplicantIncome"]])

# %%
df_1
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Property_Area  Loan_Status
# 0           0.070489                0.0  ...              2            Y
# 1           0.054830             1508.0  ...              0            N
# 2           0.035250                0.0  ...              2            Y
# 3           0.030093             2358.0  ...              2            Y
# 4           0.072356                0.0  ...              2            Y
# ..               ...                ...  ...            ...          ...
# 609         0.034014                0.0  ...              0            Y
# 610         0.048930                0.0  ...              0            Y
# 611         0.097984              240.0  ...              2            Y
# 612         0.091936                0.0  ...              2            Y
# 613         0.054830                0.0  ...              1            N
#
# [614 rows x 7 columns]

# %%
df_1.isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df_1['Loan_Amount_Term'].fillna(df_1['Loan_Amount_Term'].mode().iloc[0],inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig,ax = plt.subplots(figsize=(10, 8))
sns.distplot(df_1.LoanAmount)

# %%
df_1['LoanAmount'].fillna(df_1['LoanAmount'].median(),inplace=True)

# %%
final_train_data = df_1

# %%
final_train_data
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Property_Area  Loan_Status
# 0           0.070489                0.0  ...              2            Y
# 1           0.054830             1508.0  ...              0            N
# 2           0.035250                0.0  ...              2            Y
# 3           0.030093             2358.0  ...              2            Y
# 4           0.072356                0.0  ...              2            Y
# ..               ...                ...  ...            ...          ...
# 609         0.034014                0.0  ...              0            Y
# 610         0.048930                0.0  ...              0            Y
# 611         0.097984              240.0  ...              2            Y
# 612         0.091936                0.0  ...              2            Y
# 613         0.054830                0.0  ...              1            N
#
# [614 rows x 7 columns]

# %%
X = final_train_data.loc[:, final_train_data.columns != 'Loan_Status']
y = final_train_data['Loan_Status']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
columns = X_train.columns

# %%
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.84

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[ 20  23]
#  [  2 109]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.91      0.47      0.62        43
#            Y       0.83      0.98      0.90       111
#
#     accuracy                           0.84       154
#    macro avg       0.87      0.72      0.76       154
# weighted avg       0.85      0.84      0.82       154

# %%
y_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N'],
#       dtype=object)

# %%
from xgboost import XGBClassifier
model_2 = XGBClassifier()
model_2.fit(X_train, y_train)
y_pred_2 = model_2.predict(X_test)

# %%
y_pred_01 = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(model_2.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.84

# %%
test_data
# Out:
#       Loan_ID Gender Married  ... Loan_Amount_Term Credit_History Property_Area
# 0    LP001015   Male     Yes  ...            360.0            1.0         Urban
# 1    LP001022   Male     Yes  ...            360.0            1.0         Urban
# 2    LP001031   Male     Yes  ...            360.0            1.0         Urban
# 3    LP001035   Male     Yes  ...            360.0            NaN         Urban
# 4    LP001051   Male      No  ...            360.0            1.0         Urban
# ..        ...    ...     ...  ...              ...            ...           ...
# 362  LP002971   Male     Yes  ...            360.0            1.0         Urban
# 363  LP002975   Male     Yes  ...            360.0            1.0         Urban
# 364  LP002980   Male      No  ...            360.0            NaN     Semiurban
# 365  LP002986   Male     Yes  ...            360.0            1.0         Rural
# 366  LP002989   Male      No  ...            180.0            1.0         Rural
#
# ...

# %%
df_2= test_data[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area']].copy()

# %%
df_2
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Credit_History  Property_Area
# 0               5720                  0  ...             1.0          Urban
# 1               3076               1500  ...             1.0          Urban
# 2               5000               1800  ...             1.0          Urban
# 3               2340               2546  ...             NaN          Urban
# 4               3276                  0  ...             1.0          Urban
# ..               ...                ...  ...             ...            ...
# 362             4009               1777  ...             1.0          Urban
# 363             4158                709  ...             1.0          Urban
# 364             3250               1993  ...             NaN      Semiurban
# 365             5000               2393  ...             1.0          Rural
# 366             9200                  0  ...             1.0          Rural
#
# [367 rows x 6 columns]

# %%
df_2.isnull().sum()
# Out:
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df_2['Credit_History'].fillna(df_2['Credit_History'].mode().iloc[0],inplace=True)

# %%
le=le = preprocessing.LabelEncoder()
df_2['Property_Area'] = le.fit_transform(df_2['Property_Area'])

# %%
df_2
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Credit_History  Property_Area
# 0               5720                  0  ...             1.0              2
# 1               3076               1500  ...             1.0              2
# 2               5000               1800  ...             1.0              2
# 3               2340               2546  ...             1.0              2
# 4               3276                  0  ...             1.0              2
# ..               ...                ...  ...             ...            ...
# 362             4009               1777  ...             1.0              2
# 363             4158                709  ...             1.0              2
# 364             3250               1993  ...             1.0              1
# 365             5000               2393  ...             1.0              0
# 366             9200                  0  ...             1.0              0
#
# [367 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scale_features_mm = MinMaxScaler()
df_2["ApplicantIncome"] = scale_features_mm.fit_transform(df_2[["ApplicantIncome"]])

# %%
df_2
# Out:
#      ApplicantIncome  CoapplicantIncome  ...  Credit_History  Property_Area
# 0           0.078865                  0  ...             1.0              2
# 1           0.042411               1500  ...             1.0              2
# 2           0.068938               1800  ...             1.0              2
# 3           0.032263               2546  ...             1.0              2
# 4           0.045168                  0  ...             1.0              2
# ..               ...                ...  ...             ...            ...
# 362         0.055274               1777  ...             1.0              2
# 363         0.057329                709  ...             1.0              2
# 364         0.044810               1993  ...             1.0              1
# 365         0.068938               2393  ...             1.0              0
# 366         0.126846                  0  ...             1.0              0
#
# [367 rows x 6 columns]

# %%
model_2.fit(X,y)
y_pred11=model_2.predict(df_2)

# %%
y_pred11
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'N',
# ...

# %%
new_df=pd.DataFrame({'Loan_ID':test_data['Loan_ID'],'Loan_Status':y_pred11})

# %%
new_df
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           Y
# 2    LP001031           Y
# 3    LP001035           Y
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           Y
# 363  LP002975           Y
# 364  LP002980           Y
# 365  LP002986           Y
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
final=new_df.to_csv('submission',index =False)
